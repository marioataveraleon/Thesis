# %%
import sys

print(sys.executable)
# Out:
# c:\Users\UI450907\Desktop\TE RWEST\Tesis\TesisRepo\thesis_env\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results_path = r"C:\Users\UI450907\Desktop\TE RWEST\Tesis\Results\GFL_IEC\E1_Load_Step\E1_Load_Step.csv"
df = pd.read_csv(results_path,sep = ",")

df.head()
print(df.head(5))
# Out:
#   All calculations                         PCR                       PCR.1  \
# 0        Time in s  Electrical Frequency in Hz  Voltage, Magnitude in p.u.
# 1          -0.1000                     50.0000                      1.0000
# 2          -0.0900                     50.0000                      1.0000
# 3          -0.0800                     50.0000                      1.0000
# 4          -0.0700                     50.0000                      1.0000
#
#            EQ SG          WT Type 4B            WT Type 4B.1
# 0  Speed in p.u.  Active Power in MW  Reactive Power in Mvar
# 1         1.0000             80.0000                  0.0000
# 2         1.0000             80.0000                  0.0000
# 3         1.0000             80.0000                  0.0000
# 4         1.0000             80.0000                  0.0000
